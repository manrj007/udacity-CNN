# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob('data/lfw/*/*'))
dog_files = np.array(glob('data/dogImages/*/*/*'))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
#
# `The number of Human faces detected from human_files_short:` 96
#
# `The number of Human faces detected from dog_files_short:` 18

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
cnt = 0
for i in tqdm(range(100)):
    cnt += face_detector(human_files_short[i])
print('The number of Human faces detected from human_files_short',cnt)

cnt2 = 0
for i in tqdm(range(100)):
    cnt2 += face_detector(dog_files_short[i])
print('The number of Human faces detected from dog_files_short',cnt2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 80.80it/s]
# The number of Human faces detected from human_files_short 96
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 16.85it/s]
# The number of Human faces detected from dog_files_short 18

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %% [markdown]
# `(Optional)`
# `TODO: Report the performance of another pre-trained network.`
# `Feel free to use as many code cells as needed.`

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# %%
# check if CUDA is available
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# True

# %%
# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()
# print(VGG16)

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

# %%
for param in VGG16.parameters():
    param.requires_grad = False

# %%
torch.set_default_tensor_type('torch.cuda.FloatTensor')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
def VGG16_predict(img_path):
    picture = Image.open(img_path).convert('RGB')
    transform = transforms.Compose([transforms.Resize(size=(244, 244)), transforms.ToTensor()])
    image = transform(picture)
    image = image.to(device)   
    # Turn the input into a Variable
    # Return the top predictions and confidence scores
    image = image.unsqueeze(0)
    ret = VGG16(image)
    return torch.max(ret,1)[1].item()

# %%
VGG16_predict('images/Brittany_02625.jpg')
# Out:
# 215

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    val = VGG16_predict(img_path)
    return val>=151 and val<=268 # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %%
cnt = 0
for i in tqdm(range(100)):
    cnt += dog_detector(human_files_short[i])
print('The number of Dog faces detected from human_files_short',cnt)

cnt2 = 0
for i in tqdm(range(100)):
    cnt2 += dog_detector(dog_files_short[i])
print('The number of Dog faces detected from dog_files_short',cnt2)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 121.24it/s]
# The number of Dog faces detected from human_files_short 0
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 72.66it/s]
# The number of Dog faces detected from dog_files_short 92

# %% [markdown]
# __Answer:__
#
# The percentage of the images in __human_files_short__ is __0%__ `and`
# The percentage of the images in __dog_files_short__ is __92%__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
print('Is the given Image a face of Dog: ',dog_detector(human_files_short[10]))
print('Is the given Image a face of Dog: ',dog_detector(dog_files_short[10]))
# Out:
# Is the given Image a face of Dog:  False
# Is the given Image a face of Dog:  True

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %% [markdown]
# `(Optional)`
# `TODO: Report the performance of another pre-trained network.`
# `Feel free to use as many code cells as needed.`

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets,transforms
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

## perassigned values
batch_workers = 15
number_workers= 0

## Data path 
data_dir = 'data/dogImages/'

train_path = os.path.join(data_dir, 'train/')
val_path = os.path.join(data_dir, 'valid/')
test_path = os.path.join(data_dir, 'test/')

# %% [markdown]
# ### `Data normalisation:`

# %%
normalisation = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

transform  = {'train': transforms.Compose([transforms.RandomResizedCrop(224),
                                           transforms.RandomHorizontalFlip(),
                                           transforms.ToTensor(),normalisation]),
              'val': transforms.Compose([transforms.Resize(256),
                                         transforms.CenterCrop(224),
                                         transforms.ToTensor(),normalisation]),
              'test': transforms.Compose([transforms.Resize(size=(224,224)),
                                          transforms.ToTensor(),normalisation])
            }

# %%
train_data = datasets.ImageFolder(train_path,transform=transform["train"])
test_data = datasets.ImageFolder(test_path,transform=transform["test"])
val_data = datasets.ImageFolder(val_path,transform=transform["val"])

# %%
## Data Loading
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_workers, shuffle=True,
                                           num_workers=number_workers)

test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_workers, shuffle=True,
                                          num_workers=number_workers)

val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_workers, shuffle=True, 
                                         num_workers=number_workers)

base_loaders = {"train" : train_loader,
                "test" : test_loader,
                "val" : val_loader
               }

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:
#
# - 1. I've applied __RandomResizedCrop__ & **RandomHorizontalFlip** to just train_data. This will do both `image augmentations` and `resizing jobs`.
# - 2. Image augmentation will give randomness to the dataset so, it prevents overfitting also better performance of model can be expected when it's predicting the test_data.
# - 3. __val_data__ will be used for validation check so image augmentation will not be performed. For the __test_data__, I've applied only image resizing.

# %% [markdown]
# ### `Neural network Architecture:`

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
num_classes = 133

# %%
import torch.nn as nn
import torch.nn.functional as F
# inp = 5 * 5 * 128
# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        self.conv1 = nn.Conv2d(3, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)

        # pool
        self.pool = nn.MaxPool2d(2, 2)
        
        # fully-connected
        self.fc1 = nn.Linear(7*7*128, 500)
        self.fc2 = nn.Linear(500, num_classes) 
        
        # drop-out
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        ## Define forward behavior
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        
        # flatten
        x = x.view(-1, 7*7*128)
        
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
model_scratch = Net()


# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch = model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# **Answer**

# %% [markdown]
# ## `Defining the loss function:`

# %% [markdown]
# #### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr = 0.005)

# %% [markdown]
# ## `Training the model:`

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path, last_validation_loss=None):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    if last_validation_loss is not None:
        valid_loss_min = last_validation_loss
    else:
        valid_loss_min = np.Inf
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))

            # initialize weights to zero
            optimizer.zero_grad()
            
            output = model(data)
            
            # calculate loss
            loss = criterion(output, target)
            
            # back prop
            loss.backward()
            
            # grad
            optimizer.step()
            
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx % 100 == 0:
                print('Epoch %d, Batch %d loss: %.6f' %
                  (epoch, batch_idx + 1, train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['val']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            output = model(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            valid_loss_min = valid_loss
            
    # return trained model
    return model

# %%
# train the model
model_scratch = train(50, base_loaders, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'saved_models/model_scratch.pt')
# Out:
# Epoch 1, Batch 1 loss: 4.898673
# Epoch 1, Batch 101 loss: 4.892821
# Epoch 1, Batch 201 loss: 4.890816
# Epoch 1, Batch 301 loss: 4.889080
# Epoch 1, Batch 401 loss: 4.888427
# Epoch: 1 	Training Loss: 4.888515 	Validation Loss: 4.879319
# Validation loss decreased (inf --> 4.879319).  Saving model ...
# Epoch 2, Batch 1 loss: 4.909072
# Epoch 2, Batch 101 loss: 4.881046
# Epoch 2, Batch 201 loss: 4.875779
# Epoch 2, Batch 301 loss: 4.876555
# Epoch 2, Batch 401 loss: 4.876964
# Epoch: 2 	Training Loss: 4.876169 	Validation Loss: 4.863615
# Validation loss decreased (4.879319 --> 4.863615).  Saving model ...
# Epoch 3, Batch 1 loss: 4.882614
# Epoch 3, Batch 101 loss: 4.857374
# Epoch 3, Batch 201 loss: 4.861778
# Epoch 3, Batch 301 loss: 4.858103
# Epoch 3, Batch 401 loss: 4.859734
# Epoch: 3 	Training Loss: 4.859870 	Validation Loss: 4.847584
# Validation loss decreased (4.863615 --> 4.847584).  Saving model ...
# Epoch 4, Batch 1 loss: 4.800233
# Epoch 4, Batch 101 loss: 4.854021
# Epoch 4, Batch 201 loss: 4.853311
# Epoch 4, Batch 301 loss: 4.846183
# Epoch 4, Batch 401 loss: 4.845328
# Epoch: 4 	Training Loss: 4.844430 	Validation Loss: 4.819381
# Validation loss decreased (4.847584 --> 4.819381).  Saving model ...
# Epoch 5, Batch 1 loss: 4.877985
# Epoch 5, Batch 101 loss: 4.826560
# Epoch 5, Batch 201 loss: 4.820076
# Epoch 5, Batch 301 loss: 4.821712
# Epoch 5, Batch 401 loss: 4.817343
# Epoch: 5 	Training Loss: 4.818324 	Validation Loss: 4.769899
# Validation loss decreased (4.819381 --> 4.769899).  Saving model ...
# Epoch 6, Batch 1 loss: 4.906199
# Epoch 6, Batch 101 loss: 4.791210
# Epoch 6, Batch 201 loss: 4.786079
# Epoch 6, Batch 301 loss: 4.780149
# Epoch 6, Batch 401 loss: 4.777369
# Epoch: 6 	Training Loss: 4.777365 	Validation Loss: 4.716287
# Validation loss decreased (4.769899 --> 4.716287).  Saving model ...
# Epoch 7, Batch 1 loss: 4.641848
# Epoch 7, Batch 101 loss: 4.767565
# Epoch 7, Batch 201 loss: 4.760874
# Epoch 7, Batch 301 loss: 4.755477
# Epoch 7, Batch 401 loss: 4.754348
# Epoch: 7 	Training Loss: 4.752335 	Validation Loss: 4.678890
# Validation loss decreased (4.716287 --> 4.678890).  Saving model ...
# Epoch 8, Batch 1 loss: 4.882860
# Epoch 8, Batch 101 loss: 4.744581
# Epoch 8, Batch 201 loss: 4.728794
# Epoch 8, Batch 301 loss: 4.731460
# Epoch 8, Batch 401 loss: 4.730228
# Epoch: 8 	Training Loss: 4.727623 	Validation Loss: 4.641786
# Validation loss decreased (4.678890 --> 4.641786).  Saving model ...
# Epoch 9, Batch 1 loss: 4.787464
# Epoch 9, Batch 101 loss: 4.688491
# Epoch 9, Batch 201 loss: 4.720049
# Epoch 9, Batch 301 loss: 4.717562
# Epoch 9, Batch 401 loss: 4.716978
# Epoch: 9 	Training Loss: 4.718918 	Validation Loss: 4.634243
# Validation loss decreased (4.641786 --> 4.634243).  Saving model ...
# Epoch 10, Batch 1 loss: 4.592544
# Epoch 10, Batch 101 loss: 4.677242
# Epoch 10, Batch 201 loss: 4.703525
# Epoch 10, Batch 301 loss: 4.706446
# Epoch 10, Batch 401 loss: 4.706665
# Epoch: 10 	Training Loss: 4.702826 	Validation Loss: 4.599864
# Validation loss decreased (4.634243 --> 4.599864).  Saving model ...
# Epoch 11, Batch 1 loss: 4.523847
# Epoch 11, Batch 101 loss: 4.699464
# Epoch 11, Batch 201 loss: 4.690026
# Epoch 11, Batch 301 loss: 4.679470
# Epoch 11, Batch 401 loss: 4.684461
# Epoch: 11 	Training Loss: 4.683717 	Validation Loss: 4.588659
# Validation loss decreased (4.599864 --> 4.588659).  Saving model ...
# Epoch 12, Batch 1 loss: 4.665053
# Epoch 12, Batch 101 loss: 4.646528
# Epoch 12, Batch 201 loss: 4.669663
# Epoch 12, Batch 301 loss: 4.658349
# Epoch 12, Batch 401 loss: 4.661719
# Epoch: 12 	Training Loss: 4.660546 	Validation Loss: 4.571175
# Validation loss decreased (4.588659 --> 4.571175).  Saving model ...
# Epoch 13, Batch 1 loss: 4.603967
# Epoch 13, Batch 101 loss: 4.632257
# Epoch 13, Batch 201 loss: 4.648749
# Epoch 13, Batch 301 loss: 4.649325
# Epoch 13, Batch 401 loss: 4.639494
# Epoch: 13 	Training Loss: 4.636112 	Validation Loss: 4.533172
# Validation loss decreased (4.571175 --> 4.533172).  Saving model ...
# Epoch 14, Batch 1 loss: 4.523240
# Epoch 14, Batch 101 loss: 4.622922
# Epoch 14, Batch 201 loss: 4.618116
# Epoch 14, Batch 301 loss: 4.613378
# Epoch 14, Batch 401 loss: 4.612675
# Epoch: 14 	Training Loss: 4.612070 	Validation Loss: 4.486412
# Validation loss decreased (4.533172 --> 4.486412).  Saving model ...
# Epoch 15, Batch 1 loss: 4.388189
# Epoch 15, Batch 101 loss: 4.549367
# Epoch 15, Batch 201 loss: 4.560877
# Epoch 15, Batch 301 loss: 4.556943
# Epoch 15, Batch 401 loss: 4.562553
# Epoch: 15 	Training Loss: 4.564259 	Validation Loss: 4.449508
# Validation loss decreased (4.486412 --> 4.449508).  Saving model ...
# Epoch 16, Batch 1 loss: 4.838124
# Epoch 16, Batch 101 loss: 4.507569
# Epoch 16, Batch 201 loss: 4.511440
# Epoch 16, Batch 301 loss: 4.521651
# Epoch 16, Batch 401 loss: 4.524917
# Epoch: 16 	Training Loss: 4.523455 	Validation Loss: 4.401696
# Validation loss decreased (4.449508 --> 4.401696).  Saving model ...
# Epoch 17, Batch 1 loss: 4.552497
# Epoch 17, Batch 101 loss: 4.522584
# Epoch 17, Batch 201 loss: 4.514957
# Epoch 17, Batch 301 loss: 4.506433
# Epoch 17, Batch 401 loss: 4.510285
# Epoch: 17 	Training Loss: 4.509392 	Validation Loss: 4.371260
# Validation loss decreased (4.401696 --> 4.371260).  Saving model ...
# Epoch 18, Batch 1 loss: 4.681201
# Epoch 18, Batch 101 loss: 4.476626
# Epoch 18, Batch 201 loss: 4.488917
# Epoch 18, Batch 301 loss: 4.479151
# Epoch 18, Batch 401 loss: 4.479468
# Epoch: 18 	Training Loss: 4.478753 	Validation Loss: 4.349644
# Validation loss decreased (4.371260 --> 4.349644).  Saving model ...
# Epoch 19, Batch 1 loss: 4.517249
# Epoch 19, Batch 101 loss: 4.424634
# Epoch 19, Batch 201 loss: 4.437782
# Epoch 19, Batch 301 loss: 4.445497
# Epoch 19, Batch 401 loss: 4.452528
# Epoch: 19 	Training Loss: 4.459145 	Validation Loss: 4.321922
# Validation loss decreased (4.349644 --> 4.321922).  Saving model ...
# Epoch 20, Batch 1 loss: 4.500457
# Epoch 20, Batch 101 loss: 4.470995
# Epoch 20, Batch 201 loss: 4.456798
# Epoch 20, Batch 301 loss: 4.452522
# Epoch 20, Batch 401 loss: 4.445654
# Epoch: 20 	Training Loss: 4.446140 	Validation Loss: 4.284157
# Validation loss decreased (4.321922 --> 4.284157).  Saving model ...
# Epoch 21, Batch 1 loss: 4.203221
# Epoch 21, Batch 101 loss: 4.372643
# Epoch 21, Batch 201 loss: 4.404509
# Epoch 21, Batch 301 loss: 4.408355
# Epoch 21, Batch 401 loss: 4.416775
# Epoch: 21 	Training Loss: 4.421444 	Validation Loss: 4.262733
# Validation loss decreased (4.284157 --> 4.262733).  Saving model ...
# Epoch 22, Batch 1 loss: 4.248862
# Epoch 22, Batch 101 loss: 4.389968
# Epoch 22, Batch 201 loss: 4.387453
# Epoch 22, Batch 301 loss: 4.394507
# Epoch 22, Batch 401 loss: 4.395777
# Epoch: 22 	Training Loss: 4.400295 	Validation Loss: 4.247773
# Validation loss decreased (4.262733 --> 4.247773).  Saving model ...
# Epoch 23, Batch 1 loss: 4.316431
# Epoch 23, Batch 101 loss: 4.378653
# Epoch 23, Batch 201 loss: 4.391124
# Epoch 23, Batch 301 loss: 4.370412
# Epoch 23, Batch 401 loss: 4.365758
# Epoch: 23 	Training Loss: 4.369244 	Validation Loss: 4.205052
# Validation loss decreased (4.247773 --> 4.205052).  Saving model ...
# Epoch 24, Batch 1 loss: 4.395762
# Epoch 24, Batch 101 loss: 4.364666
# Epoch 24, Batch 201 loss: 4.381199
# Epoch 24, Batch 301 loss: 4.374222
# Epoch 24, Batch 401 loss: 4.360271
# Epoch: 24 	Training Loss: 4.359315 	Validation Loss: 4.246735
# Epoch 25, Batch 1 loss: 4.191069
# Epoch 25, Batch 101 loss: 4.366709
# Epoch 25, Batch 201 loss: 4.342529
# Epoch 25, Batch 301 loss: 4.342819
# Epoch 25, Batch 401 loss: 4.345780
# Epoch: 25 	Training Loss: 4.336398 	Validation Loss: 4.169623
# Validation loss decreased (4.205052 --> 4.169623).  Saving model ...
# Epoch 26, Batch 1 loss: 4.185813
# Epoch 26, Batch 101 loss: 4.323496
# Epoch 26, Batch 201 loss: 4.331749
# Epoch 26, Batch 301 loss: 4.326510
# Epoch 26, Batch 401 loss: 4.325504
# Epoch: 26 	Training Loss: 4.321341 	Validation Loss: 4.195531
# Epoch 27, Batch 1 loss: 4.384768
# Epoch 27, Batch 101 loss: 4.301853
# Epoch 27, Batch 201 loss: 4.302276
# Epoch 27, Batch 301 loss: 4.308063
# Epoch 27, Batch 401 loss: 4.312407
# Epoch: 27 	Training Loss: 4.315034 	Validation Loss: 4.134104
# Validation loss decreased (4.169623 --> 4.134104).  Saving model ...
# Epoch 28, Batch 1 loss: 4.220386
# Epoch 28, Batch 101 loss: 4.268188
# Epoch 28, Batch 201 loss: 4.271049
# Epoch 28, Batch 301 loss: 4.286146
# Epoch 28, Batch 401 loss: 4.288018
# Epoch: 28 	Training Loss: 4.289485 	Validation Loss: 4.123254
# Validation loss decreased (4.134104 --> 4.123254).  Saving model ...
# Epoch 29, Batch 1 loss: 4.346528
# Epoch 29, Batch 101 loss: 4.198279
# Epoch 29, Batch 201 loss: 4.252109
# Epoch 29, Batch 301 loss: 4.261052
# Epoch 29, Batch 401 loss: 4.265045
# Epoch: 29 	Training Loss: 4.264370 	Validation Loss: 4.091279
# Validation loss decreased (4.123254 --> 4.091279).  Saving model ...
# Epoch 30, Batch 1 loss: 4.203123
# Epoch 30, Batch 101 loss: 4.217700
# Epoch 30, Batch 201 loss: 4.224679
# Epoch 30, Batch 301 loss: 4.240142
# Epoch 30, Batch 401 loss: 4.241724
# Epoch: 30 	Training Loss: 4.247419 	Validation Loss: 4.072193
# Validation loss decreased (4.091279 --> 4.072193).  Saving model ...
# Epoch 31, Batch 1 loss: 4.318232
# Epoch 31, Batch 101 loss: 4.254379
# Epoch 31, Batch 201 loss: 4.226527
# Epoch 31, Batch 301 loss: 4.231953
# Epoch 31, Batch 401 loss: 4.223131
# Epoch: 31 	Training Loss: 4.219999 	Validation Loss: 4.051322
# Validation loss decreased (4.072193 --> 4.051322).  Saving model ...
# Epoch 32, Batch 1 loss: 4.263400
# Epoch 32, Batch 101 loss: 4.202993
# Epoch 32, Batch 201 loss: 4.216758
# Epoch 32, Batch 301 loss: 4.219177
# Epoch 32, Batch 401 loss: 4.203100
# Epoch: 32 	Training Loss: 4.203125 	Validation Loss: 4.041430
# Validation loss decreased (4.051322 --> 4.041430).  Saving model ...
# Epoch 33, Batch 1 loss: 4.261745
# Epoch 33, Batch 101 loss: 4.193046
# Epoch 33, Batch 201 loss: 4.202287
# Epoch 33, Batch 301 loss: 4.193011
# Epoch 33, Batch 401 loss: 4.200146
# Epoch: 33 	Training Loss: 4.204496 	Validation Loss: 4.105169
# Epoch 34, Batch 1 loss: 3.625782
# Epoch 34, Batch 101 loss: 4.130043
# Epoch 34, Batch 201 loss: 4.147013
# Epoch 34, Batch 301 loss: 4.164733
# Epoch 34, Batch 401 loss: 4.165501
# Epoch: 34 	Training Loss: 4.162757 	Validation Loss: 3.999362
# Validation loss decreased (4.041430 --> 3.999362).  Saving model ...
# Epoch 35, Batch 1 loss: 4.280341
# Epoch 35, Batch 101 loss: 4.149878
# Epoch 35, Batch 201 loss: 4.164854
# Epoch 35, Batch 301 loss: 4.152668
# Epoch 35, Batch 401 loss: 4.146886
# Epoch: 35 	Training Loss: 4.147657 	Validation Loss: 3.979862
# Validation loss decreased (3.999362 --> 3.979862).  Saving model ...
# Epoch 36, Batch 1 loss: 4.071882
# Epoch 36, Batch 101 loss: 4.139385
# Epoch 36, Batch 201 loss: 4.125035
# Epoch 36, Batch 301 loss: 4.120205
# Epoch 36, Batch 401 loss: 4.119556
# Epoch: 36 	Training Loss: 4.123879 	Validation Loss: 3.990723
# Epoch 37, Batch 1 loss: 4.330988
# Epoch 37, Batch 101 loss: 4.090363
# Epoch 37, Batch 201 loss: 4.120148
# Epoch 37, Batch 301 loss: 4.127826
# Epoch 37, Batch 401 loss: 4.126402
# Epoch: 37 	Training Loss: 4.124102 	Validation Loss: 3.955189
# Validation loss decreased (3.979862 --> 3.955189).  Saving model ...
# Epoch 38, Batch 1 loss: 4.311395
# Epoch 38, Batch 101 loss: 4.076163
# Epoch 38, Batch 201 loss: 4.083201
# Epoch 38, Batch 301 loss: 4.087999
# Epoch 38, Batch 401 loss: 4.092564
# Epoch: 38 	Training Loss: 4.090778 	Validation Loss: 3.968114
# Epoch 39, Batch 1 loss: 4.056431
# Epoch 39, Batch 101 loss: 4.075466
# Epoch 39, Batch 201 loss: 4.040661
# Epoch 39, Batch 301 loss: 4.047605
# Epoch 39, Batch 401 loss: 4.053053
# Epoch: 39 	Training Loss: 4.053678 	Validation Loss: 3.975864
# Epoch 40, Batch 1 loss: 4.227950
# Epoch 40, Batch 101 loss: 4.070399
# Epoch 40, Batch 201 loss: 4.060000
# Epoch 40, Batch 301 loss: 4.060186
# Epoch 40, Batch 401 loss: 4.055713
# Epoch: 40 	Training Loss: 4.060138 	Validation Loss: 3.897442
# Validation loss decreased (3.955189 --> 3.897442).  Saving model ...
# Epoch 41, Batch 1 loss: 4.036062
# Epoch 41, Batch 101 loss: 4.037129
# Epoch 41, Batch 201 loss: 4.038968
# Epoch 41, Batch 301 loss: 4.051188
# Epoch 41, Batch 401 loss: 4.057606
# Epoch: 41 	Training Loss: 4.053818 	Validation Loss: 4.040720
# Epoch 42, Batch 1 loss: 3.931808
# Epoch 42, Batch 101 loss: 4.019329
# Epoch 42, Batch 201 loss: 3.992986
# Epoch 42, Batch 301 loss: 4.008516
# Epoch 42, Batch 401 loss: 4.018029
# Epoch: 42 	Training Loss: 4.011467 	Validation Loss: 3.857417
# Validation loss decreased (3.897442 --> 3.857417).  Saving model ...
# Epoch 43, Batch 1 loss: 3.975056
# Epoch 43, Batch 101 loss: 3.971910
# Epoch 43, Batch 201 loss: 4.004902
# Epoch 43, Batch 301 loss: 4.013581
# Epoch 43, Batch 401 loss: 4.018952
# Epoch: 43 	Training Loss: 4.017803 	Validation Loss: 3.855736
# Validation loss decreased (3.857417 --> 3.855736).  Saving model ...
# Epoch 44, Batch 1 loss: 4.232902
# Epoch 44, Batch 101 loss: 3.929712
# Epoch 44, Batch 201 loss: 3.959944
# Epoch 44, Batch 301 loss: 3.971271
# Epoch 44, Batch 401 loss: 3.976019
# Epoch: 44 	Training Loss: 3.981706 	Validation Loss: 3.830692
# Validation loss decreased (3.855736 --> 3.830692).  Saving model ...
# Epoch 45, Batch 1 loss: 3.560524
# Epoch 45, Batch 101 loss: 3.973948
# Epoch 45, Batch 201 loss: 3.985511
# Epoch 45, Batch 301 loss: 3.966079
# Epoch 45, Batch 401 loss: 3.966501
# Epoch: 45 	Training Loss: 3.964632 	Validation Loss: 3.822160
# Validation loss decreased (3.830692 --> 3.822160).  Saving model ...
# Epoch 46, Batch 1 loss: 3.861565
# Epoch 46, Batch 101 loss: 3.892878
# Epoch 46, Batch 201 loss: 3.918947
# Epoch 46, Batch 301 loss: 3.931756
# Epoch 46, Batch 401 loss: 3.936215
# Epoch: 46 	Training Loss: 3.935138 	Validation Loss: 4.121849
# Epoch 47, Batch 1 loss: 4.501561
# Epoch 47, Batch 101 loss: 3.937457
# Epoch 47, Batch 201 loss: 3.949354
# Epoch 47, Batch 301 loss: 3.941746
# Epoch 47, Batch 401 loss: 3.947696
# Epoch: 47 	Training Loss: 3.940638 	Validation Loss: 3.814091
# Validation loss decreased (3.822160 --> 3.814091).  Saving model ...
# Epoch 48, Batch 1 loss: 3.727656
# Epoch 48, Batch 101 loss: 3.891305
# Epoch 48, Batch 201 loss: 3.891865
# Epoch 48, Batch 301 loss: 3.890845
# Epoch 48, Batch 401 loss: 3.898793
# Epoch: 48 	Training Loss: 3.904257 	Validation Loss: 3.839830
# Epoch 49, Batch 1 loss: 4.344100
# Epoch 49, Batch 101 loss: 3.889715
# Epoch 49, Batch 201 loss: 3.893356
# Epoch 49, Batch 301 loss: 3.890661
# Epoch 49, Batch 401 loss: 3.897143
# Epoch: 49 	Training Loss: 3.900241 	Validation Loss: 3.779978
# Validation loss decreased (3.814091 --> 3.779978).  Saving model ...
# Epoch 50, Batch 1 loss: 3.959638
# Epoch 50, Batch 101 loss: 3.890584
# Epoch 50, Batch 201 loss: 3.851021
# Epoch 50, Batch 301 loss: 3.866334
# Epoch 50, Batch 401 loss: 3.862555
# Epoch: 50 	Training Loss: 3.868661 	Validation Loss: 3.758192
# Validation loss decreased (3.779978 --> 3.758192).  Saving model ...

# %% [markdown]
# ## `Testing the model:`

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %% [markdown]
# `Loading the saved model`

# %%
model_scratch.load_state_dict(torch.load('saved_models/model_scratch.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
def test(loaders, model, criterion, use_cuda):
    test_loss = 0.
    correct = 0.
    total = 0.
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # GPU move
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass
        output = model(data)
        # loss calc.
        loss = criterion(output, target)
        # updating average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # converting output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # comparing predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (100. * correct / total, correct, total))

# %%
test(base_loaders, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.894580
#
#
# Test Accuracy: 11% (96/836)

# %% [markdown]
# ## `Transfer Learning`

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
base_loaders_transfer = base_loaders.copy()

# %%
model_transfer = models.vgg16(pretrained=True)
use_cuda = torch.cuda.is_available()
print(use_cuda)
if use_cuda:
    model_transfer = model_transfer.cuda()
# Out:
# True

# %%
for param in model_transfer.parameters():
    param.requires_grad = True

torch.set_default_tensor_type('torch.cuda.FloatTensor')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(filter(lambda p: p.requires_grad, model_transfer.parameters()),lr= 0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path, last_validation_loss=None):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    if last_validation_loss is not None:
        valid_loss_min = last_validation_loss
    else:
        valid_loss_min = np.Inf
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))

            # initialize weights to zero
            optimizer.zero_grad()
            
            output = model(data)
            
            # calculate loss
            loss = criterion(output, target)
            
            # back prop
            loss.backward()
            
            # grad
            optimizer.step()
            
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx % 100 == 0:
                print('Epoch %d, Batch %d loss: %.6f' %
                  (epoch, batch_idx + 1, train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['val']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            output = model(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            valid_loss_min = valid_loss
        
    return model

# %%
# train the model
model_transfer = train(50, base_loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer,
                       use_cuda, 'saved_models/model_transfer.pt')
# Out:
# Epoch 1, Batch 1 loss: 18.714235
# Epoch 1, Batch 101 loss: 6.642862
# Epoch 1, Batch 201 loss: 6.166796
# Epoch 1, Batch 301 loss: 5.971259
# Epoch 1, Batch 401 loss: 5.834890
# Epoch: 1 	Training Loss: 5.778189 	Validation Loss: 5.103455
# Validation loss decreased (inf --> 5.103455).  Saving model ...
# Epoch 2, Batch 1 loss: 5.339270
# Epoch 2, Batch 101 loss: 5.194949
# Epoch 2, Batch 201 loss: 5.126235
# Epoch 2, Batch 301 loss: 5.079179
# Epoch 2, Batch 401 loss: 5.032627
# Epoch: 2 	Training Loss: 5.004917 	Validation Loss: 4.501978
# Validation loss decreased (5.103455 --> 4.501978).  Saving model ...
# Epoch 3, Batch 1 loss: 5.029946
# Epoch 3, Batch 101 loss: 4.726352
# Epoch 3, Batch 201 loss: 4.693541
# Epoch 3, Batch 301 loss: 4.651270
# Epoch 3, Batch 401 loss: 4.594799
# Epoch: 3 	Training Loss: 4.575507 	Validation Loss: 3.910269
# Validation loss decreased (4.501978 --> 3.910269).  Saving model ...
# Epoch 4, Batch 1 loss: 4.494034
# Epoch 4, Batch 101 loss: 4.266200
# Epoch 4, Batch 201 loss: 4.219661
# Epoch 4, Batch 301 loss: 4.168596
# Epoch 4, Batch 401 loss: 4.129474
# Epoch: 4 	Training Loss: 4.114847 	Validation Loss: 3.198353
# Validation loss decreased (3.910269 --> 3.198353).  Saving model ...
# Epoch 5, Batch 1 loss: 4.188699
# Epoch 5, Batch 101 loss: 3.721421
# Epoch 5, Batch 201 loss: 3.692881
# Epoch 5, Batch 301 loss: 3.639952
# Epoch 5, Batch 401 loss: 3.598633
# Epoch: 5 	Training Loss: 3.576940 	Validation Loss: 2.526052
# Validation loss decreased (3.198353 --> 2.526052).  Saving model ...
# Epoch 6, Batch 1 loss: 3.091002
# Epoch 6, Batch 101 loss: 3.251569
# Epoch 6, Batch 201 loss: 3.193119
# Epoch 6, Batch 301 loss: 3.157711
# Epoch 6, Batch 401 loss: 3.121387
# Epoch: 6 	Training Loss: 3.100768 	Validation Loss: 2.057388
# Validation loss decreased (2.526052 --> 2.057388).  Saving model ...
# Epoch 7, Batch 1 loss: 3.280463
# Epoch 7, Batch 101 loss: 2.752003
# Epoch 7, Batch 201 loss: 2.735058
# Epoch 7, Batch 301 loss: 2.710302
# Epoch 7, Batch 401 loss: 2.704411
# Epoch: 7 	Training Loss: 2.681191 	Validation Loss: 1.648430
# Validation loss decreased (2.057388 --> 1.648430).  Saving model ...
# Epoch 8, Batch 1 loss: 2.653128
# Epoch 8, Batch 101 loss: 2.507584
# Epoch 8, Batch 201 loss: 2.500452
# Epoch 8, Batch 301 loss: 2.459186
# Epoch 8, Batch 401 loss: 2.426747
# Epoch: 8 	Training Loss: 2.422904 	Validation Loss: 1.418341
# Validation loss decreased (1.648430 --> 1.418341).  Saving model ...
# Epoch 9, Batch 1 loss: 2.874666
# Epoch 9, Batch 101 loss: 2.231952
# Epoch 9, Batch 201 loss: 2.186381
# Epoch 9, Batch 301 loss: 2.176586
# Epoch 9, Batch 401 loss: 2.165353
# Epoch: 9 	Training Loss: 2.158157 	Validation Loss: 1.285005
# Validation loss decreased (1.418341 --> 1.285005).  Saving model ...
# Epoch 10, Batch 1 loss: 1.905300
# Epoch 10, Batch 101 loss: 1.850456
# Epoch 10, Batch 201 loss: 1.945704
# Epoch 10, Batch 301 loss: 1.976448
# Epoch 10, Batch 401 loss: 1.982581
# Epoch: 10 	Training Loss: 1.972103 	Validation Loss: 1.111424
# Validation loss decreased (1.285005 --> 1.111424).  Saving model ...
# Epoch 11, Batch 1 loss: 2.642514
# Epoch 11, Batch 101 loss: 1.894906
# Epoch 11, Batch 201 loss: 1.898938
# Epoch 11, Batch 301 loss: 1.880704
# Epoch 11, Batch 401 loss: 1.861554
# Epoch: 11 	Training Loss: 1.858805 	Validation Loss: 0.987520
# Validation loss decreased (1.111424 --> 0.987520).  Saving model ...
# Epoch 12, Batch 1 loss: 2.212202
# Epoch 12, Batch 101 loss: 1.706212
# Epoch 12, Batch 201 loss: 1.728157
# Epoch 12, Batch 301 loss: 1.712111
# Epoch 12, Batch 401 loss: 1.701866
# Epoch: 12 	Training Loss: 1.698986 	Validation Loss: 0.867899
# Validation loss decreased (0.987520 --> 0.867899).  Saving model ...
# Epoch 13, Batch 1 loss: 2.113912
# Epoch 13, Batch 101 loss: 1.663542
# Epoch 13, Batch 201 loss: 1.665041
# Epoch 13, Batch 301 loss: 1.641774
# Epoch 13, Batch 401 loss: 1.617124
# Epoch: 13 	Training Loss: 1.605838 	Validation Loss: 0.834998
# Validation loss decreased (0.867899 --> 0.834998).  Saving model ...
# Epoch 14, Batch 1 loss: 2.071014
# Epoch 14, Batch 101 loss: 1.474942
# Epoch 14, Batch 201 loss: 1.482830
# Epoch 14, Batch 301 loss: 1.501692
# Epoch 14, Batch 401 loss: 1.515643
# Epoch: 14 	Training Loss: 1.522084 	Validation Loss: 0.820943
# Validation loss decreased (0.834998 --> 0.820943).  Saving model ...
# Epoch 15, Batch 1 loss: 2.426251
# Epoch 15, Batch 101 loss: 1.433300
# Epoch 15, Batch 201 loss: 1.427855
# Epoch 15, Batch 301 loss: 1.422458
# Epoch 15, Batch 401 loss: 1.435422
# Epoch: 15 	Training Loss: 1.428107 	Validation Loss: 0.710681
# Validation loss decreased (0.820943 --> 0.710681).  Saving model ...
# Epoch 16, Batch 1 loss: 1.625410
# Epoch 16, Batch 101 loss: 1.416005
# Epoch 16, Batch 201 loss: 1.420264
# Epoch 16, Batch 301 loss: 1.390371
# Epoch 16, Batch 401 loss: 1.412270
# Epoch: 16 	Training Loss: 1.405801 	Validation Loss: 0.676876
# Validation loss decreased (0.710681 --> 0.676876).  Saving model ...
# Epoch 17, Batch 1 loss: 1.131200
# Epoch 17, Batch 101 loss: 1.327507
# Epoch 17, Batch 201 loss: 1.315289
# Epoch 17, Batch 301 loss: 1.309554
# Epoch 17, Batch 401 loss: 1.320735
# Epoch: 17 	Training Loss: 1.324547 	Validation Loss: 0.641874
# Validation loss decreased (0.676876 --> 0.641874).  Saving model ...
# Epoch 18, Batch 1 loss: 1.145167
# Epoch 18, Batch 101 loss: 1.226757
# Epoch 18, Batch 201 loss: 1.233989
# Epoch 18, Batch 301 loss: 1.256696
# Epoch 18, Batch 401 loss: 1.288615
# Epoch: 18 	Training Loss: 1.289350 	Validation Loss: 0.585720
# Validation loss decreased (0.641874 --> 0.585720).  Saving model ...
# Epoch 19, Batch 1 loss: 1.381439
# Epoch 19, Batch 101 loss: 1.293872
# Epoch 19, Batch 201 loss: 1.260387
# Epoch 19, Batch 301 loss: 1.262150
# Epoch 19, Batch 401 loss: 1.258589
# Epoch: 19 	Training Loss: 1.251974 	Validation Loss: 0.584340
# Validation loss decreased (0.585720 --> 0.584340).  Saving model ...
# Epoch 20, Batch 1 loss: 1.434408
# Epoch 20, Batch 101 loss: 1.215224
# Epoch 20, Batch 201 loss: 1.193298
# Epoch 20, Batch 301 loss: 1.192524
# Epoch 20, Batch 401 loss: 1.191984
# Epoch: 20 	Training Loss: 1.186460 	Validation Loss: 0.605883
# Epoch 21, Batch 1 loss: 1.445881
# Epoch 21, Batch 101 loss: 1.108809
# Epoch 21, Batch 201 loss: 1.137350
# Epoch 21, Batch 301 loss: 1.150402
# Epoch 21, Batch 401 loss: 1.149795
# Epoch: 21 	Training Loss: 1.150322 	Validation Loss: 0.584488
# Epoch 22, Batch 1 loss: 0.484490
# Epoch 22, Batch 101 loss: 1.087793
# Epoch 22, Batch 201 loss: 1.076762
# Epoch 22, Batch 301 loss: 1.099398
# Epoch 22, Batch 401 loss: 1.095143
# Epoch: 22 	Training Loss: 1.093712 	Validation Loss: 0.527334
# Validation loss decreased (0.584340 --> 0.527334).  Saving model ...
# Epoch 23, Batch 1 loss: 0.737387
# Epoch 23, Batch 101 loss: 0.998618
# Epoch 23, Batch 201 loss: 1.011538
# Epoch 23, Batch 301 loss: 1.066142
# Epoch 23, Batch 401 loss: 1.077190
# Epoch: 23 	Training Loss: 1.078921 	Validation Loss: 0.526305
# Validation loss decreased (0.527334 --> 0.526305).  Saving model ...
# Epoch 24, Batch 1 loss: 1.139068
# Epoch 24, Batch 101 loss: 1.087284
# Epoch 24, Batch 201 loss: 1.097428
# Epoch 24, Batch 301 loss: 1.080565
# Epoch 24, Batch 401 loss: 1.083614
# Epoch: 24 	Training Loss: 1.084803 	Validation Loss: 0.610282
# Epoch 25, Batch 1 loss: 1.035339
# Epoch 25, Batch 101 loss: 1.092590
# Epoch 25, Batch 201 loss: 1.059951
# Epoch 25, Batch 301 loss: 1.070050
# Epoch 25, Batch 401 loss: 1.054046
# Epoch: 25 	Training Loss: 1.050601 	Validation Loss: 0.523635
# Validation loss decreased (0.526305 --> 0.523635).  Saving model ...
# Epoch 26, Batch 1 loss: 1.266508
# Epoch 26, Batch 101 loss: 1.045800
# Epoch 26, Batch 201 loss: 1.058459
# Epoch 26, Batch 301 loss: 1.029765
# Epoch 26, Batch 401 loss: 1.027163
# Epoch: 26 	Training Loss: 1.031090 	Validation Loss: 0.511552
# Validation loss decreased (0.523635 --> 0.511552).  Saving model ...
# Epoch 27, Batch 1 loss: 0.672403
# Epoch 27, Batch 101 loss: 0.967579
# Epoch 27, Batch 201 loss: 1.004748
# Epoch 27, Batch 301 loss: 1.025098
# Epoch 27, Batch 401 loss: 1.017878
# Epoch: 27 	Training Loss: 1.013389 	Validation Loss: 0.506110
# Validation loss decreased (0.511552 --> 0.506110).  Saving model ...
# Epoch 28, Batch 1 loss: 0.900784
# Epoch 28, Batch 101 loss: 0.950077
# Epoch 28, Batch 201 loss: 0.975823
# Epoch 28, Batch 301 loss: 0.963276
# Epoch 28, Batch 401 loss: 0.960328
# Epoch: 28 	Training Loss: 0.959158 	Validation Loss: 0.487210
# Validation loss decreased (0.506110 --> 0.487210).  Saving model ...
# Epoch 29, Batch 1 loss: 1.142061
# Epoch 29, Batch 101 loss: 0.963505
# Epoch 29, Batch 201 loss: 0.941029
# Epoch 29, Batch 301 loss: 0.959472
# Epoch 29, Batch 401 loss: 0.950196
# Epoch: 29 	Training Loss: 0.944281 	Validation Loss: 0.501800
# Epoch 30, Batch 1 loss: 1.636003
# Epoch 30, Batch 101 loss: 0.954316
# Epoch 30, Batch 201 loss: 0.963863
# Epoch 30, Batch 301 loss: 0.956756
# Epoch 30, Batch 401 loss: 0.940928
# Epoch: 30 	Training Loss: 0.931889 	Validation Loss: 0.456028
# Validation loss decreased (0.487210 --> 0.456028).  Saving model ...
# Epoch 31, Batch 1 loss: 0.894777
# Epoch 31, Batch 101 loss: 0.934098
# Epoch 31, Batch 201 loss: 0.894432
# Epoch 31, Batch 301 loss: 0.895627
# Epoch 31, Batch 401 loss: 0.902354
# Epoch: 31 	Training Loss: 0.919397 	Validation Loss: 0.480195
# Epoch 32, Batch 1 loss: 0.967092
# Epoch 32, Batch 101 loss: 0.891214
# Epoch 32, Batch 201 loss: 0.892982
# Epoch 32, Batch 301 loss: 0.891717
# Epoch 32, Batch 401 loss: 0.894359
# Epoch: 32 	Training Loss: 0.900535 	Validation Loss: 0.459608
# Epoch 33, Batch 1 loss: 0.687053
# Epoch 33, Batch 101 loss: 0.951375
# Epoch 33, Batch 201 loss: 0.895273
# Epoch 33, Batch 301 loss: 0.891448
# Epoch 33, Batch 401 loss: 0.902334
# Epoch: 33 	Training Loss: 0.897113 	Validation Loss: 0.474339
# Epoch 34, Batch 1 loss: 0.781619
# Epoch 34, Batch 101 loss: 0.831116
# Epoch 34, Batch 201 loss: 0.839866
# Epoch 34, Batch 301 loss: 0.868769
# Epoch 34, Batch 401 loss: 0.889079
# Epoch: 34 	Training Loss: 0.881728 	Validation Loss: 0.475278
# Epoch 35, Batch 1 loss: 0.284671
# Epoch 35, Batch 101 loss: 0.798526
# Epoch 35, Batch 201 loss: 0.827601
# Epoch 35, Batch 301 loss: 0.846926
# Epoch 35, Batch 401 loss: 0.842801
# Epoch: 35 	Training Loss: 0.844779 	Validation Loss: 0.469259
# Epoch 36, Batch 1 loss: 0.682817
# Epoch 36, Batch 101 loss: 0.892418
# Epoch 36, Batch 201 loss: 0.875828
# Epoch 36, Batch 301 loss: 0.844815
# Epoch 36, Batch 401 loss: 0.839139
# Epoch: 36 	Training Loss: 0.847472 	Validation Loss: 0.545057
# Epoch 37, Batch 1 loss: 0.841011
# Epoch 37, Batch 101 loss: 0.774795
# Epoch 37, Batch 201 loss: 0.814553
# Epoch 37, Batch 301 loss: 0.820108
# Epoch 37, Batch 401 loss: 0.819405
# Epoch: 37 	Training Loss: 0.825599 	Validation Loss: 0.486146
# Epoch 38, Batch 1 loss: 0.892171
# Epoch 38, Batch 101 loss: 0.790966
# Epoch 38, Batch 201 loss: 0.803723
# Epoch 38, Batch 301 loss: 0.841059
# Epoch 38, Batch 401 loss: 0.846453
# Epoch: 38 	Training Loss: 0.840526 	Validation Loss: 0.525930
# Epoch 39, Batch 1 loss: 1.503406
# Epoch 39, Batch 101 loss: 0.832099
# Epoch 39, Batch 201 loss: 0.806661
# Epoch 39, Batch 301 loss: 0.814411
# Epoch 39, Batch 401 loss: 0.805277
# Epoch: 39 	Training Loss: 0.801631 	Validation Loss: 0.448073
# Validation loss decreased (0.456028 --> 0.448073).  Saving model ...
# Epoch 40, Batch 1 loss: 0.215636
# Epoch 40, Batch 101 loss: 0.845577
# Epoch 40, Batch 201 loss: 0.826427
# Epoch 40, Batch 301 loss: 0.842297
# Epoch 40, Batch 401 loss: 0.809035
# Epoch: 40 	Training Loss: 0.814420 	Validation Loss: 0.449063
# Epoch 41, Batch 1 loss: 0.518608
# Epoch 41, Batch 101 loss: 0.766324
# Epoch 41, Batch 201 loss: 0.786521
# Epoch 41, Batch 301 loss: 0.807346
# Epoch 41, Batch 401 loss: 0.803298
# Epoch: 41 	Training Loss: 0.806130 	Validation Loss: 0.596416
# Epoch 42, Batch 1 loss: 0.313739
# Epoch 42, Batch 101 loss: 0.844621
# Epoch 42, Batch 201 loss: 0.789858
# Epoch 42, Batch 301 loss: 0.784062
# Epoch 42, Batch 401 loss: 0.782966
# Epoch: 42 	Training Loss: 0.781724 	Validation Loss: 0.444163
# Validation loss decreased (0.448073 --> 0.444163).  Saving model ...
# Epoch 43, Batch 1 loss: 0.437429
# Epoch 43, Batch 101 loss: 0.819689
# Epoch 43, Batch 201 loss: 0.787155
# Epoch 43, Batch 301 loss: 0.790336
# Epoch 43, Batch 401 loss: 0.792163
# Epoch: 43 	Training Loss: 0.796660 	Validation Loss: 0.459619
# Epoch 44, Batch 1 loss: 0.417829
# Epoch 44, Batch 101 loss: 0.689147
# Epoch 44, Batch 201 loss: 0.754391
# Epoch 44, Batch 301 loss: 0.752941
# Epoch 44, Batch 401 loss: 0.766395
# Epoch: 44 	Training Loss: 0.766211 	Validation Loss: 0.475088
# Epoch 45, Batch 1 loss: 0.592521
# Epoch 45, Batch 101 loss: 0.753643
# Epoch 45, Batch 201 loss: 0.751763
# Epoch 45, Batch 301 loss: 0.763572
# Epoch 45, Batch 401 loss: 0.765261
# Epoch: 45 	Training Loss: 0.764950 	Validation Loss: 0.476830
# Epoch 46, Batch 1 loss: 1.611442
# Epoch 46, Batch 101 loss: 0.715801
# Epoch 46, Batch 201 loss: 0.736360
# Epoch 46, Batch 301 loss: 0.751756
# Epoch 46, Batch 401 loss: 0.736631
# Epoch: 46 	Training Loss: 0.730342 	Validation Loss: 0.485730
# Epoch 47, Batch 1 loss: 0.412668
# Epoch 47, Batch 101 loss: 0.708890
# Epoch 47, Batch 201 loss: 0.745252
# Epoch 47, Batch 301 loss: 0.750707
# Epoch 47, Batch 401 loss: 0.738395
# Epoch: 47 	Training Loss: 0.741721 	Validation Loss: 0.442672
# Validation loss decreased (0.444163 --> 0.442672).  Saving model ...
# Epoch 48, Batch 1 loss: 1.125146
# Epoch 48, Batch 101 loss: 0.709533
# Epoch 48, Batch 201 loss: 0.706320
# Epoch 48, Batch 301 loss: 0.689361
# Epoch 48, Batch 401 loss: 0.701483
# Epoch: 48 	Training Loss: 0.709941 	Validation Loss: 0.444978
# Epoch 49, Batch 1 loss: 0.954290
# Epoch 49, Batch 101 loss: 0.660666
# Epoch 49, Batch 201 loss: 0.666612
# Epoch 49, Batch 301 loss: 0.681306
# Epoch 49, Batch 401 loss: 0.705430
# Epoch: 49 	Training Loss: 0.708656 	Validation Loss: 0.425197
# Validation loss decreased (0.442672 --> 0.425197).  Saving model ...
# Epoch 50, Batch 1 loss: 0.614051
# Epoch 50, Batch 101 loss: 0.689866
# Epoch 50, Batch 201 loss: 0.670491
# Epoch 50, Batch 301 loss: 0.693952
# Epoch 50, Batch 401 loss: 0.696028
# Epoch: 50 	Training Loss: 0.694373 	Validation Loss: 0.467569

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
model_transfer.load_state_dict(torch.load('saved_models/model_transfer.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
test(base_loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.584505
#
#
# Test Accuracy: 84% (710/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]

class_names = [item[4:].replace("_", " ") for item in base_loaders_transfer['train'].dataset.classes]

# %%
base_loaders_transfer['train'].dataset.classes[:5]
# Out:
# ['001.Affenpinscher',
#  '002.Afghan_hound',
#  '003.Airedale_terrier',
#  '004.Akita',
#  '005.Alaskan_malamute']

# %%
class_names[:5]
# Out:
# ['Affenpinscher',
#  'Afghan hound',
#  'Airedale terrier',
#  'Akita',
#  'Alaskan malamute']

# %%
from PIL import Image
import torchvision.transforms as transforms

def load_input_image(img_path):    
    image = Image.open(img_path).convert('RGB')
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     normalisation])

    # discard the transparent, alpha channel (that's the :3) and add the batch dimension
    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    return image

# %%
def predict_breed_transfer(model, class_names, img_path):
    # load the image and return the predicted breed
    img = load_input_image(img_path)
    model = model.cpu()
    model.eval()
    idx = torch.argmax(model(img))
    return class_names[idx]

# %%
for img_file in os.listdir('images/'):
    img_path = os.path.join('images/', img_file)
    predition = predict_breed_transfer(model_transfer, class_names, img_path)
    print("predicted breed: \t{0}".format(predition))
# Out:
# predicted breed: 	American water spaniel
# predicted breed: 	Brittany
# predicted breed: 	Curly-coated retriever
# predicted breed: 	Labrador retriever
# predicted breed: 	Chesapeake bay retriever
# predicted breed: 	Labrador retriever
# predicted breed: 	Nova scotia duck tolling retriever
# predicted breed: 	Greyhound
# predicted breed: 	Golden retriever
# predicted breed: 	Welsh springer spaniel

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
for img_file in os.listdir('images/'):
    img_path = os.path.join('images/', img_file)
    run_app(img_path)
# Out:
# Dogs Detected!
# It looks like a American water spaniel
# Dogs Detected!
# It looks like a Brittany
# Dogs Detected!
# It looks like a Curly-coated retriever
# Dogs Detected!
# It looks like a Labrador retriever
# Dogs Detected!
# It looks like a Chesapeake bay retriever
# Dogs Detected!
# It looks like a Labrador retriever
# Error! Can't detect anything..
# Dogs Detected!
# It looks like a Greyhound
# Hello, human!
# If you were a dog..You may look like a Golden retriever
# Dogs Detected!
# It looks like a Welsh springer spaniel

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)
# Out:
# Hello, human!
# If you were a dog..You may look like a Affenpinscher
# Hello, human!
# If you were a dog..You may look like a Pharaoh hound
# Error! Can't detect anything..
# Dogs Detected!
# It looks like a Affenpinscher
# Dogs Detected!
# It looks like a Affenpinscher
# Dogs Detected!
# It looks like a Affenpinscher

# %%
my_human_files = ['images/sample_human_output.png', 'data/lfw/AJ_Lamas/AJ_Lamas_0001.jpg',
                  'data/lfw/Aaron_Pena/Aaron_Pena_0001.jpg']
my_dog_files = ['data/sample/Brittany_02625.jpg', 'data/sample/photo-1507146426996-ef05306b995a.jpg',
                'data/dogImages/train/004.Akita/Akita_00225.jpg']

# %%
for img in np.hstack([my_human_files,my_dog_files]):
    run_app(img)
# Out:
# Hello, human!
# If you were a dog..You may look like a Golden retriever
# Hello, human!
# If you were a dog..You may look like a Labrador retriever
# Hello, human!
# If you were a dog..You may look like a Beagle
# Dogs Detected!
# It looks like a Brittany
# Dogs Detected!
# It looks like a Cocker spaniel
# Dogs Detected!
# It looks like a Akita
